# %% [markdown]
# # Set up
# env = Python 3.11.4 eds220-env

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Global Dam Watch Data
gdw = gpd.read_file("data/raw/GDW_v1_0_gdb/GDW_v1_0.gdb")

# ICOLD Data 
icold = pd.read_excel("data/raw/world_register_dams_2025.xlsx")
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# File /opt/anaconda3/envs/eds220-env/lib/python3.11/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#
#     134 try:
#
# --> 135     module = importlib.import_module(name)
#
#     136 except ImportError:
#
#
#
# File /opt/anaconda3/envs/eds220-env/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#
#     125         level += 1
#
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
#
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
#
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
#
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
#
#
# ModuleNotFoundError: No module named 'openpyxl'
#
#
#
# ...

# %%
gdw.ORIG_SRC.unique()
# Out:
# array(['GRanD', 'GOODD', 'GOODD-NID', 'Other', 'GROD', 'JRC-GSW', 'FHReD',
#        'GROD-NID', 'JRC-NID'], dtype=object)
